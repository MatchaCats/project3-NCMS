# %%
import pandas as pd
from pprint import pprint
pd.options.display.max_colwidth = 200
mentalhealth_df = pd.read_csv("../mental_health_and_technology_usage_2024.csv")
mentalhealth_df
# Out:
#          User_ID  Age  Gender  Technology_Usage_Hours  \
# 0     USER-00001   23  Female                    6.57
# 1     USER-00002   21    Male                    3.01
# 2     USER-00003   51    Male                    3.04
# 3     USER-00004   25  Female                    3.84
# 4     USER-00005   53    Male                    1.20
# ...          ...  ...     ...                     ...
# 9995  USER-09996   42    Male                    7.05
# 9996  USER-09997   31   Other                    3.12
# 9997  USER-09998   23    Male                    4.38
# 9998  USER-09999   38    Male                    4.44
# 9999  USER-10000   41    Male                    2.50
#
#       Social_Media_Usage_Hours  Gaming_Hours  Screen_Time_Hours  \
# 0                         6.00          0.68              12.36
# 1                         2.57          3.74               7.61
# 2                         6.14          1.26               3.16
# ...

# %%
dataframe = mentalhealth_df.to_json()
dataframe
# Out:
# '{"User_ID":{"0":"USER-00001","1":"USER-00002","2":"USER-00003","3":"USER-00004","4":"USER-00005","5":"USER-00006","6":"USER-00007","7":"USER-00008","8":"USER-00009","9":"USER-00010","10":"USER-00011","11":"USER-00012","12":"USER-00013","13":"USER-00014","14":"USER-00015","15":"USER-00016","16":"USER-00017","17":"USER-00018","18":"USER-00019","19":"USER-00020","20":"USER-00021","21":"USER-00022","22":"USER-00023","23":"USER-00024","24":"USER-00025","25":"USER-00026","26":"USER-00027","27":"USER-00028","28":"USER-00029","29":"USER-00030","30":"USER-00031","31":"USER-00032","32":"USER-00033","33":"USER-00034","34":"USER-00035","35":"USER-00036","36":"USER-00037","37":"USER-00038","38":"USER-00039","39":"USER-00040","40":"USER-00041","41":"USER-00042","42":"USER-00043","43":"USER-00044","44":"USER-00045","45":"USER-00046","46":"USER-00047","47":"USER-00048","48":"USER-00049","49":"USER-00050","50":"USER-00051","51":"USER-00052","52":"USER-00053","53":"USER-00054","54":"USER-00055","55":
# ...

# %%
columns = mentalhealth_df.columns.tolist()
columns

# %%
user_ID = mentalhealth_df['User_ID'].tolist()

# %%
age = mentalhealth_df['Age'].tolist()

# %%
gender = mentalhealth_df['Gender'].tolist()

# %%
technology_usage_hours = mentalhealth_df['Technology_Usage_Hours'].tolist()

# %%
social_media_usage_hours = mentalhealth_df['Social_Media_Usage_Hours'].tolist()

# %%
gaming_hours = mentalhealth_df['Gaming_Hours'].tolist()

# %%
screen_time_hours = mentalhealth_df['Screen_Time_Hours'].tolist()

# %%
mental_health_status = mentalhealth_df['Mental_Health_Status'].tolist()

# %%
stress_level = mentalhealth_df['Stress_Level'].tolist()

# %%
sleep_hours = mentalhealth_df['Sleep_Hours'].tolist()

# %%
physical_activity_hours = mentalhealth_df['Physical_Activity_Hours'].tolist()
